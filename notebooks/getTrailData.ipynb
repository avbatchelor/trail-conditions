# %% [markdown]
# # Download and parse data from newenglandtrailconditions.com

# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_html(id):
    # Request webpage
    url = "http://www.newenglandtrailconditions.com/nh/viewreport.php?entryid=" + str(id)
    result = requests.get(url)

    # Check that it was received 
    if result.status_code == 200:
        return result
    else:
        print('Page ' + str(id) + ' not downloaded.')

# %% [markdown]
# ## Create empty data frame

# %%
edited_column_names = ['entry_id','peaks', 'trails', 'date_of_hike', 'parking_access', 'surface_conditions', 'equipment', 'water_crossings', 'trail_maintenance', 'dogs', 'bugs', 'lost_and_found', 'comments', 'name', 'email', 'date_submitted', 'link']
df = pd.DataFrame(columns = edited_column_names,index= range(0,1))
df.set_index('entry_id',inplace=True)
df.head()
# Out:
#          peaks trails date_of_hike parking_access surface_conditions  \
# entry_id
# NaN        NaN    NaN          NaN            NaN                NaN
#
#          equipment water_crossings trail_maintenance dogs bugs lost_and_found  \
# entry_id
# NaN            NaN             NaN               NaN  NaN  NaN            NaN
#
#          comments name email date_submitted link
# entry_id
# NaN           NaN  NaN   NaN            NaN  NaN

# %% [markdown]
# ## Parse table into dataframe

# %%
def html_to_df(result)

    # Parse html 
    soup = BeautifulSoup(result.text, 'html.parser')

    # Select the table containing hike report 
    table = soup.find_all('table')[2] 

    # Code adapted from: http://srome.github.io/Parsing-HTML-Tables-in-Python-with-BeautifulSoup-and-pandas/
    # 2018/02/10
    n_rows = 0 
    row_marker = 0
    column_marker = 1

    for row in table.find_all('tr'):

        # If the row contains 3 columns, add 1 to the number of rows 
        td_tags = row.find_all('td')
        if len(td_tags) == 3:
            n_rows += 1
            df.iat[row_marker,column_marker] = td_tags[2].get_text()
            column_marker += 1

    df.head()
# Out:
#   entry_id                       peaks  \
# 0      NaN  Mt. Flume, Mt. Liberty, NH
#
#                                               trails  \
# 0  Liberty Spring Trail, Flume Slide Trail, Franc...
#
#                date_of_hike  \
# 0  Sunday, February 4, 2018
#
#                                       parking_access  \
# 0  Flume Visitors Center. Plowed with a light lay...
#
#                                   surface_conditions  \
# 0  Dry Trail, Ice - Blue, Snow - Packed Powder/Lo...
#
#                             equipment  \
# 0  Light Traction, Traction, Ice Axe
#
#                                      water_crossings  \
# 0  A combination of stable snow bridges and a lit...
#
#                                    trail_maintenance  \
# 0  A few crawl unders and one or two easy walk ar...
#
#                                                 dogs bugs lost_and_found  \
# 0  One happy husky? on my way down Liberty Spring...
#
#                                             comments  name  \
# 0  Three inches of new powder over a firm and wel...  Len
#
#                      email date_submitted       link
# 0  lsampson_1@charter.net    2018-02-04    \nhttp://

# %% [markdown]
# ## Make entry id index column

# %%
df.loc[test_id] = result_list
df.head()
# Out:
#                                peaks  \
# entry_id
# NaN                              NaN
#  34386.0  Mt. Flume, Mt. Liberty, NH
#
#                                                      trails  \
# entry_id
# NaN                                                     NaN
#  34386.0  Liberty Spring Trail, Flume Slide Trail, Franc...
#
#                       date_of_hike  \
# entry_id
# NaN                            NaN
#  34386.0  Sunday, February 4, 2018
#
#                                              parking_access  \
# entry_id
# NaN                                                     NaN
#  34386.0  Flume Visitors Center. Plowed with a light lay...
#
#                                          surface_conditions  \
# entry_id
# NaN                                                     NaN
#  34386.0  Dry Trail, Ice - Blue, Snow - Packed Powder/Lo...
#
#                                    equipment  \
# entry_id
# NaN                                      NaN
#  34386.0  Light Traction, Traction, Ice Axe
#
#                                             water_crossings  \
# entry_id
# NaN                                                     NaN
#  34386.0  A combination of stable snow bridges and a lit...
#
#                                           trail_maintenance  \
# entry_id
# NaN                                                     NaN
#  34386.0  A few crawl unders and one or two easy walk ar...
#
#                                                        dogs bugs  \
# entry_id
# NaN                                                     NaN  NaN
#  34386.0  One happy husky? on my way down Liberty Spring...
#
#          lost_and_found                                           comments  \
# entry_id
# NaN                 NaN                                                NaN
#  34386.0                 Three inches of new powder over a firm and wel...
#
#           name                    email date_submitted       link
# entry_id
# NaN        NaN                      NaN            NaN        NaN
#  34386.0  Len   lsampson_1@charter.net    2018-02-04    \nhttp://

# %%
test_id = 34386

# %%
test_id = 34386
result = get_html(test_id)

# %%
result_list = html_to_df(result)
print(result_list)
# Out:
# ['Mt. Flume, Mt. Liberty, NH', 'Liberty Spring Trail, Flume Slide Trail, Franconia Ridge Trail', 'Sunday, February 4, 2018', 'Flume Visitors Center. Plowed with a light layer of new powder.\xa0', 'Dry Trail, Ice - Blue, Snow - Packed Powder/Loose Granular, Snow - Unpacked Powder, Snow/Ice - Frozen Granular, Snow - Drifts, Snow/Ice - Postholes, Slush, Snow/Ice - Small Patches\xa0', 'Light Traction, Traction, Ice Axe\xa0', 'A combination of stable snow bridges and a little rock hopping. Water levels were low\xa0', 'A few crawl unders and one or two easy walk arounds\xa0', 'One happy husky? on my way down Liberty Springs Trail. He was clearly in his element.\xa0', '\xa0', '\xa0', 'Three inches of new powder over a firm and well broken-out Liberty Springs Trail. Microspikes were great except in a few slushy sections that balled up the bottoms. Flume Slide Trail was less broken out, but got by with microspikes on the flatter section. There were a few hidden post holes (probably from the warm weather a few weeks back). I did manage to tweak a knee in one, though. Changed to crampons and broke out my ice axe on the slide section. Lots of ice flows and powder-covered stretches of ice that made things tricky. Bushwacked to the side of one of the larger flows early on. Great day overall. Saw three hikers on my way down Liberty Springs Trail - not one else. \xa0', 'Len\xa0', 'lsampson_1@charter.net\xa0', '2018-02-04\xa0 ', '\nhttp://']

# %%
def html_to_df(result):

    # Parse html 
    soup = BeautifulSoup(result.text, 'html.parser')

    # Select the table containing hike report 
    table = soup.find_all('table')[2] 

    # Code adapted from: http://srome.github.io/Parsing-HTML-Tables-in-Python-with-BeautifulSoup-and-pandas/
    # 2018/02/10
    column_marker = 1
    result_list = []

    for row in table.find_all('tr'):

        # If the row contains 3 columns, add 1 to the number of rows 
        td_tags = row.find_all('td')
        if len(td_tags) == 3:
            result_list.append(td_tags[2].get_text())
            column_marker += 1

    return result_list
