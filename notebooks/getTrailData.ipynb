# %% [markdown]
# # Download and parse data from newenglandtrailconditions.com

# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Request webpage
entry_id = 34386
url = "http://www.newenglandtrailconditions.com/nh/viewreport.php?entryid=" + str(entry_id)
result = requests.get(url)

# Check that it was received 
result.status_code
# Out:
# 200

# %%
# Parse html 
soup = BeautifulSoup(result.text, 'html.parser')

# See what it looks like 
# print(soup.prettify())

# %%
# Select the table containing hike report 
table = soup.find_all('table')[2]

# %% [markdown]
# ## Create empty data frame

# %%
edited_column_names = ['entry_id','peaks', 'trails', 'date_of_hike', 'parking_access', 'surface_conditions', 'equipment', 'water_crossings', 'trail_maintenance', 'dogs', 'bugs', 'lost_and_found', 'comments', 'name', 'email', 'date_submitted', 'link']
df = pd.DataFrame(columns = edited_column_names,index= range(0,1))
df.head()
# Out:
#   entry_id peaks trails date_of_hike parking_access surface_conditions  \
# 0      NaN   NaN    NaN          NaN            NaN                NaN
#
#   equipment water_crossings trail_maintenance dogs bugs lost_and_found  \
# 0       NaN             NaN               NaN  NaN  NaN            NaN
#
#   comments name email date_submitted link
# 0      NaN  NaN   NaN            NaN  NaN

# %% [markdown]
# ## Parse table into dataframe

# %%
# Code adapted from: http://srome.github.io/Parsing-HTML-Tables-in-Python-with-BeautifulSoup-and-pandas/
# 2018/02/10
n_rows = 0 
row_marker = 0
column_marker = 1

for row in table.find_all('tr'):
       
    # If the row contains 3 columns, add 1 to the number of rows 
    td_tags = row.find_all('td')
    if len(td_tags) == 3:
        n_rows += 1
        df.iat[row_marker,column_marker] = td_tags[2].get_text()
        column_marker += 1
        
df.head()
# Out:
#   entry_id                       peaks  \
# 0      NaN  Mt. Flume, Mt. Liberty, NH
#
#                                               trails  \
# 0  Liberty Spring Trail, Flume Slide Trail, Franc...
#
#                date_of_hike  \
# 0  Sunday, February 4, 2018
#
#                                       parking_access  \
# 0  Flume Visitors Center. Plowed with a light lay...
#
#                                   surface_conditions  \
# 0  Dry Trail, Ice - Blue, Snow - Packed Powder/Lo...
#
#                             equipment  \
# 0  Light Traction, Traction, Ice Axe
#
#                                      water_crossings  \
# 0  A combination of stable snow bridges and a lit...
#
#                                    trail_maintenance  \
# 0  A few crawl unders and one or two easy walk ar...
#
#                                                 dogs bugs lost_and_found  \
# 0  One happy husky? on my way down Liberty Spring...
#
#                                             comments  name  \
# 0  Three inches of new powder over a firm and wel...  Len
#
#                      email date_submitted       link
# 0  lsampson_1@charter.net    2018-02-04    \nhttp://

# %% [markdown]
# ## Make entry id index column

# %%
df.loc[0,'entry_id'] = entry_id
df.head()
# Out:
#   entry_id                       peaks  \
# 0    34386  Mt. Flume, Mt. Liberty, NH
#
#                                               trails  \
# 0  Liberty Spring Trail, Flume Slide Trail, Franc...
#
#                date_of_hike  \
# 0  Sunday, February 4, 2018
#
#                                       parking_access  \
# 0  Flume Visitors Center. Plowed with a light lay...
#
#                                   surface_conditions  \
# 0  Dry Trail, Ice - Blue, Snow - Packed Powder/Lo...
#
#                             equipment  \
# 0  Light Traction, Traction, Ice Axe
#
#                                      water_crossings  \
# 0  A combination of stable snow bridges and a lit...
#
#                                    trail_maintenance  \
# 0  A few crawl unders and one or two easy walk ar...
#
#                                                 dogs bugs lost_and_found  \
# 0  One happy husky? on my way down Liberty Spring...
#
#                                             comments  name  \
# 0  Three inches of new powder over a firm and wel...  Len
#
#                      email date_submitted       link
# 0  lsampson_1@charter.net    2018-02-04    \nhttp://

# %% [markdown]
# ## Set index

# %%
df.set_index('entry_id',inplace=True)
df.head()
# Out:
#                                peaks  \
# entry_id
# 34386     Mt. Flume, Mt. Liberty, NH
#
#                                                      trails  \
# entry_id
# 34386     Liberty Spring Trail, Flume Slide Trail, Franc...
#
#                       date_of_hike  \
# entry_id
# 34386     Sunday, February 4, 2018
#
#                                              parking_access  \
# entry_id
# 34386     Flume Visitors Center. Plowed with a light lay...
#
#                                          surface_conditions  \
# entry_id
# 34386     Dry Trail, Ice - Blue, Snow - Packed Powder/Lo...
#
#                                    equipment  \
# entry_id
# 34386     Light Traction, Traction, Ice Axe
#
#                                             water_crossings  \
# entry_id
# 34386     A combination of stable snow bridges and a lit...
#
#                                           trail_maintenance  \
# entry_id
# 34386     A few crawl unders and one or two easy walk ar...
#
#                                                        dogs bugs  \
# entry_id
# 34386     One happy husky? on my way down Liberty Spring...
#
#          lost_and_found                                           comments  \
# entry_id
# 34386                    Three inches of new powder over a firm and wel...
#
#           name                    email date_submitted       link
# entry_id
# 34386     Len   lsampson_1@charter.net    2018-02-04    \nhttp://
